# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df_life_exp = pd.read_csv('../data/life_exp.csv')

# %%
df_life_exp.head(100)
# Out:
#    LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 0       AUS   LIFEEXP     MEN      YR         A  1960   67.9        NaN
# 1       AUS   LIFEEXP     MEN      YR         A  1961   68.0        NaN
# 2       AUS   LIFEEXP     MEN      YR         A  1962   67.8        NaN
# 3       AUS   LIFEEXP     MEN      YR         A  1963   67.9        NaN
# 4       AUS   LIFEEXP     MEN      YR         A  1964   67.5        NaN
# ..      ...       ...     ...     ...       ...   ...    ...        ...
# 95      AUS   LIFEEXP     TOT      YR         A  1997   78.5        NaN
# 96      AUS   LIFEEXP     TOT      YR         A  1998   78.7        NaN
# 97      AUS   LIFEEXP     TOT      YR         A  1999   79.0        NaN
# 98      AUS   LIFEEXP     TOT      YR         A  2000   79.3        NaN
# 99      AUS   LIFEEXP     TOT      YR         A  2001   79.7        NaN
#
# [100 rows x 8 columns]

# %%
df_life_exp_time = df_life_exp[df_life_exp['TIME'] > 1979]
df_life_exp_tot = df_life_exp_time[df_life_exp_time['SUBJECT'] == 'TOT']

# %%
fig = px.line(df_life_exp_tot, x="TIME", y="Value", title='Global Life Expectancy', color="LOCATION",
              line_group="LOCATION", hover_name="LOCATION")
fig.show()
# Out:
# <div>
#
#
#             <div id="57646970-da74-41e4-85b5-dff5f2a200f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57646970-da74-41e4-85b5-dff5f2a200f1")) {
#                     Plotly.newPlot(
#                         '57646970-da74-41e4-85b5-dff5f2a200f1',
# ...

# %%
fig = px.line(df_life_exp_tot, x="TIME", y="Value", title='Global Life Expectancy', color="LOCATION",
              line_group="LOCATION", hover_name="LOCATION")
fig.show()
# Out:
# <div>
#
#
#             <div id="ee57160d-69d2-41c4-9d68-dbda4de8a899" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee57160d-69d2-41c4-9d68-dbda4de8a899")) {
#                     Plotly.newPlot(
#                         'ee57160d-69d2-41c4-9d68-dbda4de8a899',
# ...

# %%
df_life_exp_US = df_life_exp_tot[df_life_exp_tot['LOCATION'] == 'USA']
fig = px.line(df_life_exp_US, x="TIME", y="Value", title='Global Life Expectancy', color="LOCATION",
              line_group="LOCATION", hover_name="LOCATION")
fig.show()
# Out:
# <div>
#
#
#             <div id="0b7c1cfe-ac5f-4301-998a-710c3553796c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b7c1cfe-ac5f-4301-998a-710c3553796c")) {
#                     Plotly.newPlot(
#                         '0b7c1cfe-ac5f-4301-998a-710c3553796c',
# ...
